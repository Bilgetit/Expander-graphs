# %%
import numpy as np
from typing import Optional
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd
from matplotlib import cm
from multiprocessing import Pool
from sympy import isprime
import time
from size import degree
from estimate_c import get_c
from plot_c import print_table

df = pd.read_csv('/Users/mikkelgjestrud/Documents/Prosjekter/Expander-graphs/table_2_101_0.01_0.5.csv')
df.set_index('|A|/|V|', inplace=True)
df.style
# print(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ff23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ff23_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_3ff23_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_3ff23_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_3ff23_level0_col3" class="col_heading level0 col3" >17</th>
#       <th id="T_3ff23_level0_col4" class="col_heading level0 col4" >19</th>
#       <th id="T_3ff23_level0_col5" class="col_heading level0 col5" >23</th>
#       <th id="T_3ff23_level0_col6" class="col_heading level0 col6" >29</th>
#       <th id="T_3ff23_level0_col7" class="col_heading level0 col7" >31</th>
#       <th id="T_3ff23_level0_col8" class="col_heading level0 col8" >37</th>
#       <th id="T_3ff23_level0_col9" class="col_heading level0 col9" >41</th>
#       <th id="T_3ff23_level0_col10" class="col_heading level0 col10" >43</th>
# ...

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
s2 = df.style.applymap(style_negative, props='color:red;')

def highlight_max(s, props=''):
    return np.where(s == np.nanmin(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:red', axis=0)

s2.to_latex('/Users/mikkelgjestrud/Documents/Prosjekter/Expander-graphs/table_2_101_0.01_0.5.tex')

s2
# Out:
# <style type="text/css">
# #T_0836b_row0_col9, #T_0836b_row0_col12, #T_0836b_row0_col14, #T_0836b_row0_col15, #T_0836b_row0_col18, #T_0836b_row1_col7, #T_0836b_row1_col8, #T_0836b_row2_col4, #T_0836b_row3_col19, #T_0836b_row4_col3, #T_0836b_row5_col2, #T_0836b_row8_col6, #T_0836b_row8_col13, #T_0836b_row8_col21, #T_0836b_row13_col1, #T_0836b_row13_col17, #T_0836b_row13_col20, #T_0836b_row16_col10, #T_0836b_row16_col16, #T_0836b_row17_col0, #T_0836b_row23_col11, #T_0836b_row26_col5 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_0836b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0836b_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_0836b_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_0836b_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_0836b_level0_col3" class="col_heading level0 col3" >17</th>
# ...

# %%
df = pd.read_csv('/Users/mikkelgjestrud/Documents/Prosjekter/Expander-graphs/table_2_101_0.001_0.01.csv')
df.set_index('|A|/|V|', inplace=True)
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7296">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7296_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_f7296_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_f7296_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_f7296_level0_col3" class="col_heading level0 col3" >17</th>
#       <th id="T_f7296_level0_col4" class="col_heading level0 col4" >19</th>
#       <th id="T_f7296_level0_col5" class="col_heading level0 col5" >23</th>
#       <th id="T_f7296_level0_col6" class="col_heading level0 col6" >29</th>
#       <th id="T_f7296_level0_col7" class="col_heading level0 col7" >31</th>
#       <th id="T_f7296_level0_col8" class="col_heading level0 col8" >37</th>
#       <th id="T_f7296_level0_col9" class="col_heading level0 col9" >41</th>
#       <th id="T_f7296_level0_col10" class="col_heading level0 col10" >43</th>
# ...

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
s2 = df.style.applymap(style_negative, props='color:red;')

def highlight_max(s, props=''):
    return np.where(s == np.nanmin(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:red', axis=0)

s2.to_latex('/Users/mikkelgjestrud/Documents/Prosjekter/Expander-graphs/table_2_101_0.001_0.01(second).tex')

s2
# Out:
# <style type="text/css">
# #T_93648_row13_col20, #T_93648_row14_col18, #T_93648_row14_col19, #T_93648_row14_col21, #T_93648_row16_col15, #T_93648_row17_col16, #T_93648_row17_col17, #T_93648_row18_col11, #T_93648_row23_col14, #T_93648_row24_col12, #T_93648_row25_col0, #T_93648_row25_col3, #T_93648_row25_col13, #T_93648_row26_col0, #T_93648_row26_col1, #T_93648_row26_col5, #T_93648_row26_col9, #T_93648_row27_col0, #T_93648_row27_col1, #T_93648_row27_col2, #T_93648_row27_col7, #T_93648_row27_col10, #T_93648_row28_col0, #T_93648_row28_col2, #T_93648_row28_col4, #T_93648_row28_col6, #T_93648_row28_col8 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_93648">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93648_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_93648_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_93648_level0_col2" class="col_heading level0 col2" >13</th>
# ...
